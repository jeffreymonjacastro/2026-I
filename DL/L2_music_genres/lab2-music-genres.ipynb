# %% [markdown]
# # Lab 2 - Music Genres

# %% [markdown]
# ## Importando Database

# %%
import os

path = "/kaggle/input/datasets/jeffreyamc/music-genres-lab/test/test"

files = os.listdir(path)
print(f'Total de archivos/carpetas: {len(files)}')
#display(files)
# Out:
# Total de archivos/carpetas: 6240

# %%
import pandas as pd

df = pd.read_csv(f"{path}train.csv")

df['Target'].value_counts().sort_index()
# Out:
# Target
# 0       56
# 1      464
# 2      134
# 3     4733
# 4     1687
# 5     1138
# 6     1644
# 7     1012
# 8      763
# 9      288
# 10     383
# 11     889
# 12    5323
# 13     116
# 14      89
# Name: count, dtype: int64
